# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input,Dense
from tensorflow.keras.optimizers import SGD
import pandas as pd

# %%
data = pd.read_csv("diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
x_train = data[['Pregnancies','Glucose','BloodPressure']]
y_train = data[['SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome']]

# %%
model = Sequential()
model.add(Dense(3,activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(6,activation = 'relu'))

sgd = SGD(lr=0.1)

model.compile(loss='CategoricalCrossentropy',optimizer=sgd,metrics=['accuracy'])
model.fit(x_train,y_train,epochs=100,batch_size=10)
# Out:
# Epoch 1/100
# c:\Users\Sannath\.conda\envs\tensorflow\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 77/77 [==============================] - 0s 744us/step - loss: 745.8354 - accuracy: 0.4375
# Epoch 2/100
# 77/77 [==============================] - 0s 866us/step - loss: 526.1974 - accuracy: 0.2969
# Epoch 3/100
# 77/77 [==============================] - 0s 921us/step - loss: 513.6563 - accuracy: 0.1797
# Epoch 4/100
# 77/77 [==============================] - 0s 932us/step - loss: 500.9505 - accuracy: 0.3216
# Epoch 5/100
# 77/77 [==============================] - 0s 966us/step - loss: 495.0860 - accuracy: 0.4948
# Epoch 6/100
# 77/77 [==============================] - 0s 888us/step - loss: 492.0223 - accuracy: 0.4948
# Epoch 7/100
# 77/77 [==============================] - 0s 947us/step - loss: 490.5000 - accuracy: 0.4948
# Epoch 8/100
# ...

# %%
X = data.drop(['Outcome'],axis=1)
Y = data['Outcome']

# %%
model2 = Sequential()
model2.add(Dense(7,activation='relu'))
model2.add(Dense(16,activation='relu'))
model2.add(Dense(16,activation='relu'))
model2.add(Dense(16,activation='relu'))
model2.add(Dense(1,activation='relu'))
model2.compile(loss='CategoricalCrossentropy',optimizer='adam',metrics=['accuracy'])
model2.fit(X,Y,epochs=150,batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.6471
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6510
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6510
# Epoch 4/150
# 77/77 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6510
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6510
# Epoch 6/150
# 77/77 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6510
# Epoch 7/150
# 77/77 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6510
# Epoch 8/150
# 77/77 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6510
# Epoch 9/150
# 77/77 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.6510
# Epoch 10/150
# ...
